# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Iris.csv")
print(df)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
for i in range( len(df.columns)):
  if(df.dtypes[i] == object):
    print(df.columns[i], ": Nominal")
  else:
    print(df.columns[i], ": Numerical")
# Out:
# Id : Numerical
# SepalLengthCm : Numerical
# SepalWidthCm : Numerical
# PetalLengthCm : Numerical
# PetalWidthCm : Numerical
# Species : Nominal

# %%
fig = plt.figure(figsize = (10,15))
ax = fig.gca()
df1 = df.drop(columns = ["Id"])
# df2 = df1["SepalLengthCm"]
df1.hist(ax = ax)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   """
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fd7bc37fc90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd7bc368d10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fd7bc32b250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd7bc2e2750>]],
#       dtype=object)

# %%
fig = plt.figure(figsize = (15,5))
ax = fig.gca()
df.plot(subplots=True, kind = 'box', ax = ax)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/plotting/_matplotlib/__init__.py:71: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   plot_obj.generate()
# Id                  AxesSubplot(0.125,0.125;0.133621x0.755)
# SepalLengthCm    AxesSubplot(0.285345,0.125;0.133621x0.755)
# SepalWidthCm      AxesSubplot(0.44569,0.125;0.133621x0.755)
# PetalLengthCm    AxesSubplot(0.606034,0.125;0.133621x0.755)
# PetalWidthCm     AxesSubplot(0.766379,0.125;0.133621x0.755)
# dtype: object
